# %%
import numpy as np
import pandas as pd
from pathlib import Path

import xarray as xr
from pycocotools.coco import COCO
import netCDF4

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

from utils.PAD_datamodule import PADDataModule
from utils.settings.config import CROP_ENCODING, IMG_SIZE, LINEAR_ENCODER
# Out:
# Seed set to 16
# Seed set to 16

# %%
def get_window(idx, window_len, image_size, coco_file):
        '''
        Returns the DataSet index for a given patch id and the
        number of subpatches belonging to this patch.

        Patch indexing starts from 0.
        '''
        num_patches = len(COCO(coco_file).imgs)
        print("num_patches", num_patches)
        num_subpatches = ((IMG_SIZE // image_size[0]), (IMG_SIZE // image_size[1]))
        subpatch_id = idx * (num_subpatches[0] * num_subpatches[1])

        print("subpatch_id, num_subpatches", subpatch_id, num_subpatches)
        return subpatch_id, num_subpatches

# %%
# Define paths
root_coco_path = Path('coco_files')
coco_train = root_coco_path / 'exp1_patches5000_strat_coco_train.json'
coco_val = root_coco_path / 'exp1_patches5000_strat_coco_val.json'

root_data_path = Path('dataset/')
netcdf_path = root_data_path / 'netcdf'

# %%
coco_train
# Out:
# PosixPath('coco_files/exp1_patches5000_strat_coco_train.json')

# %%
# Create Data Module
dm = PADDataModule(
    netcdf_path=netcdf_path,
    path_train=coco_train,
    path_val=coco_val,
    group_freq='1MS',
    prefix='exp1_patches5000_strat',
    bands=['B02', 'B03', 'B04', 'B08'],
    linear_encoder=LINEAR_ENCODER,
    saved_medians=True,
    window_len=6,
    requires_norm=True,
    return_masks=False,
    clouds=False,
    cirrus=False,
    shadow=False,
    snow=False,
    output_size=[61, 61],
    batch_size=1,
    num_workers=2,
    binary_labels=False,
    return_parcels=True
)

# TRAINING
dm.setup('fit')
# Out:
# loading annotations into memory...
# Done (t=14.82s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=4.89s)
# creating index...
# index created!
# self.medians_dir logs/medians/exp1_patches5000_strat_medians_1MS_B02B03B04B08/train
# self.medians_dir logs/medians/exp1_patches5000_strat_medians_1MS_B02B03B04B08/val

# %%
fig, axes = plt.subplots(2, 4, figsize=(30, 15))

image_idx1 = 2

# Image B02
subpatch_id, num_subpatches = get_window(image_idx1 - 1, 6, [61, 61], coco_train)

print("subpatch_id, num_subpatches", subpatch_id, num_subpatches)

grid = ImageGrid(fig, 241, nrows_ncols=(num_subpatches[0], num_subpatches[1]), axes_pad=0.0)
for idx in range(num_subpatches[0] * num_subpatches[1]):
    print("subpatch_id + idx", subpatch_id + idx)
    batch = dm.dataset_train.__getitem__(subpatch_id + idx)
    #batch = dm.dataset_train.__getitem__(2)
    grid[idx].imshow(batch['medians'][0, 0, :, :], vmin=0, vmax=1)

print("anything")

# Image B03
subpatch_id, num_subpatches = get_window(image_idx1 - 1, 6, [61, 61], coco_train)
grid = ImageGrid(fig, 242, nrows_ncols=(num_subpatches[0], num_subpatches[1]), axes_pad=0.0)
for idx in range(num_subpatches[0] * num_subpatches[1]):
    batch = dm.dataset_train.__getitem__(subpatch_id + idx)
    grid[idx].imshow(batch['medians'][0, 1, :, :], vmin=0, vmax=1)
    
# Image B04
subpatch_id, num_subpatches = get_window(image_idx1 - 1, 6, [61, 61], coco_train)
grid = ImageGrid(fig, 243, nrows_ncols=(num_subpatches[0], num_subpatches[1]), axes_pad=0.0)
for idx in range(num_subpatches[0] * num_subpatches[1]):
    batch = dm.dataset_train.__getitem__(subpatch_id + idx)
    grid[idx].imshow(batch['medians'][0, 2, :, :], vmin=0, vmax=1)
    
# Image B08
subpatch_id, num_subpatches = get_window(image_idx1 - 1, 6, [61, 61], coco_train)
grid = ImageGrid(fig, 244, nrows_ncols=(num_subpatches[0], num_subpatches[1]), axes_pad=0.0)
for idx in range(num_subpatches[0] * num_subpatches[1]):
    batch = dm.dataset_train.__getitem__(subpatch_id + idx)
    grid[idx].imshow(batch['medians'][0, 3, :, :], vmin=0, vmax=1)
    
# Label
subpatch_id, num_subpatches = get_window(image_idx1 - 1, 6, [61, 61], coco_train)
grid = ImageGrid(fig, 245, nrows_ncols=(num_subpatches[0], num_subpatches[1]), axes_pad=0.0)
for idx in range(num_subpatches[0] * num_subpatches[1]):
    batch = dm.dataset_train.__getitem__(subpatch_id + idx)
    grid[idx].imshow(batch['labels'].squeeze(), vmin=0, vmax=max(LINEAR_ENCODER.values()))

title_font = {'size': '14'}
axes[0][0].set_title(f'Image {image_idx1}: B02', fontdict=title_font)
axes[0][1].set_title(f'Image {image_idx1}: B03', fontdict=title_font)
axes[0][2].set_title(f'Image {image_idx1}: B04', fontdict=title_font)
axes[0][3].set_title(f'Image {image_idx1}: B08', fontdict=title_font)
axes[1][0].set_title(f'Label', fontdict=title_font)
# Out:
# loading annotations into memory...
# Done (t=18.85s)
# creating index...
# index created!
# num_patches 3000
# subpatch_id, num_subpatches 36 (6, 6)
# subpatch_id, num_subpatches 36 (6, 6)
# subpatch_id + idx 36
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 13
#      11 for idx in range(num_subpatches[0] * num_subpatches[1]):
#      12     print("subpatch_id + idx", subpatch_id + idx)
# ---> 13     batch = dm.dataset_train.__getitem__(subpatch_id + idx)
#      14     #batch = dm.dataset_train.__getitem__(2)
#      15     grid[idx].imshow(batch['medians'][0, 0, :, :], vmin=0, vmax=1)
#
# File ~/S4A-Models/utils/PAD_dataset.py:425, in PADDataset.__getitem__(self, idx)
#     421 patch_id = self.patch_ids[patch_id]
#     423 if self.saved_medians:
#     424     # They are already computed, therefore we just load them
# --> 425     print("medians_dir", medians_dir)
#     426     print("patch_id", patch_id)
#     427     block_dir = Path(self.medians_dir) / str(patch_id)
#
# NameError: name 'medians_dir' is not defined
